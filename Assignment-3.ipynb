# %%
1. Why are functions advantageous to have in your programs?
We can reduce the size of our code by using function i.e.
if we have a code clock which is being used multiple time we can write that code block 
in a function, and instead of repeatedly writing the code again and again for different values 
we can just call the function with parameter which reduces the compilation and run time of our program.



2. When does the code in a function run: when it's specified or when it's called?
A code in a function runs only when a function is called.


3. What statement creates a function?
A return statement created a function. A return statements is nothing but a values which 
will be returned, when a code in function runs upon function call.


4. What is the difference between a function and a function call?
A function is procedure to achieve a particular result while 
function call is using this function to achive that task.


5. How many  scopes are there in a Python program? What is local variable scopes?
There are 4 scope in python
Local, Global, Built-in, Enclosed

The variables created inside the function is called local variable. We can access local variable 
only inside the function.



6. What happens to variables in a local scope when the function call returns?
A local variable retains its value until the next time the function is called. A local variable 
becomes undefined after the function call completes. The local variable can be used outside the
 function any time after the function call completes.


7. What is the concept of a return value? Is it possible to have a return value in an expression?
The a function return a value when its call is completed, this value is called a return value.
Yes an expression can return a value.

for example.
def add(x,y):
return x*y:

the above expression in retrun will return x*y


8. If a function does not have a return statement, what is the return value of a call to that function?
A function will not return anything if there is no return statement, and it will not return anything even when it is called


9. How do you make a function variable refer to the global variable?
We need to use keyword global while declaring the local variable inside the function.
for example:-
def f():
    global s
    s = ' GFG'
    print(s)


10. What is the data type of None?
None is not the same as 0, False, or an empty string. 
None is a data type of its own (NoneType) and only None can be None.


11. What does the sentence import areallyourpetsnamederic do?
That import statement imports a module named areallyourpetsnamederic. 
(This isn’t a real Python module, by the way.) 
This function can be called with spam.bacon ().


12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
This function can be called with spam.bacon ()

13. What can you do to save a programme from crashing if it encounters an error?
When program encounters an error, the control can be passed to the except block, 
skipping the code in between.


14. What is the purpose of the try clause? What is the purpose of the except clause?
The idea of the try-except clause is to handle exceptions (errors at runtime).
