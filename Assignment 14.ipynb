# %% [raw]
# 1. **What does RGBA stand for?**
# RGBA stands for Red, Green, Blue, and Alpha. It is a color model that represents colors using a combination of red, green, and blue channels, along with an alpha channel for transparency.
#
# 2. **From the Pillow module, how do you get the RGBA value of any images?**
# To get the RGBA (red, green, blue, alpha) value of any image using the Pillow module, you can use the `getpixel()` method. Here's an example:
# ```python
# from PIL import Image
#
# # Open an image
# image = Image.open('image.jpg')
#
# # Get the RGBA value of a pixel at coordinates (x, y)
# rgba = image.getpixel((x, y))
# ```
#
# 3. **What is a box tuple, and how does it work?**
# A box tuple is a tuple that represents a rectangular region or bounding box. It consists of four values: (left, upper, right, lower), where left is the x-coordinate of the left edge, upper is the y-coordinate of the upper edge, right is the x-coordinate of the right edge, and lower is the y-coordinate of the lower edge. The box tuple defines the region of interest within an image.
#
# 4. **Use your image and load in notebook then, how can you find out the width and height of an Image object?**
# To find out the width and height of an Image object in Python using the Pillow module, you can use the `size` attribute. Here's an example:
# ```python
# from PIL import Image
#
# # Open an image
# image = Image.open('image.jpg')
#
# # Get the width and height
# width, height = image.size
# ```
#
# 5. **What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?**
# To get an Image object for a 100x100 image, excluding the lower-left quarter, you can use the `crop()` method. Here's an example:
# ```python
# from PIL import Image
#
# # Open an image
# image = Image.open('image.jpg')
#
# # Crop the image to exclude the lower-left quarter
# cropped_image = image.crop((0, 0, 50, 50))  # Adjust the coordinates according to your needs
# ```
#
# 6. **After making changes to an Image object, how could you save it as an image file?**
# To save changes made to an Image object as an image file, you can use the `save()` method. Here's an example:
# ```python
# from PIL import Image
#
# # Open an image
# image = Image.open('image.jpg')
#
# # Make changes to the image
#
# # Save the modified image
# image.save('modified_image.jpg')
# ```
#
# 7. **What module contains Pillow’s shape-drawing code?**
# Pillow's shape-drawing code is contained in the `ImageDraw` module.
#
# 8. **Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?**
# The `ImageDraw` object has drawing methods for shapes and text. You can obtain an `ImageDraw` object by calling the `ImageDraw.Draw()` function, passing it the Image object. Here's an example:
# ```python
# from PIL import Image, ImageDraw
#
# # Open an image
# image = Image.open('image.jpg')
#
# # Create an ImageDraw object
# draw = ImageDraw.Draw(image)
#
# # Use the drawing methods on the ImageDraw object
# draw.rectangle((x1, y1, x2, y2), outline='red')
#
# # Save the modified image
# image.save('modified_image.jpg')
# ```
